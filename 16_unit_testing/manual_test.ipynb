# %% [markdown]
# # Manual Testing of Vector Class

# %% [markdown]
# #### uv pipinstall pytest
# https://chatgpt.com/c/6901d9ee-6fb4-8332-b5a9-82a73cf7be88

# %% [markdown]
# ![Screenshot 2025-10-29 101157.png](<attachment:Screenshot 2025-10-29 101157.png>)

# %% [markdown]
# ### Virtual Environment
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Pytest to work
# 1. Go to the folder
# 2. .venv/Scripts/activate
# 3. pytest --version
# 4. cd to the folder
# 5. pytest

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"""
import the Vector module from vector.py
"""

from vector import Vector

# vector with coordinate 2 and 5
v1 = Vector(2, 5)
v1
# Out:
# Vector(2.0, 5.0)

# %%
v2 = Vector(1, 1)

# %%
print(f"{v1.numbers = }")
# Out:
# v1.numbers = (2.0, 5.0)

# %%
print(f"{v1 + v2 = }")
# Out:
# v1 + v2 = Vector(3.0, 6.0)

# %% [markdown]
# ## testing correct errors

# %%
try:
    Vector("1", 3)
except TypeError as err:
    print(err)
# Out:
# 1 is not a valid number in a vector

# %%
# addition of 2 vectors with different lengths

v1 = Vector(1, 2)
v2 = Vector(1, 2, 3)
try:
    v1 + v2
except TypeError as err:
    print(err)
# Out:
# Both must be Vectors and have the same length

# %% [markdown]
# ## Assert will be used in automatic testing

# %%
x = 5
assert x == 5
